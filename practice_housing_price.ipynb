# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("USA_Housing.csv")

# %%
df
# Out:
#       Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0        79545.458574            5.682861                  7.009188
# 1        79248.642455            6.002900                  6.730821
# 2        61287.067179            5.865890                  8.512727
# 3        63345.240046            7.188236                  5.586729
# 4        59982.197226            5.040555                  7.839388
# 5        80175.754159            4.988408                  6.104512
# 6        64698.463428            6.025336                  8.147760
# 7        78394.339278            6.989780                  6.620478
# 8        59927.660813            5.362126                  6.393121
# 9        81885.927184            4.423672                  8.167688
# 10       80527.472083            8.093513                  5.042747
# 11       50593.695497            4.496513                  7.467627
# 12       68804.286404            7.671755                  7.250029
# ...

# %%
df.shape
# Out:
# (5000, 7)

# %%
df.head()
# Out:
#    Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0     79545.458574            5.682861                  7.009188
# 1     79248.642455            6.002900                  6.730821
# 2     61287.067179            5.865890                  8.512727
# 3     63345.240046            7.188236                  5.586729
# 4     59982.197226            5.040555                  7.839388
#
#    Avg_Area_Number_of_Bedrooms  Area_Population         Price  \
# 0                         4.09     23086.800503  1.059034e+06
# 1                         3.09     40173.072174  1.505891e+06
# 2                         5.13     36882.159400  1.058988e+06
# 3                         3.26     34310.242831  1.260617e+06
# 4                         4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\r\nLaurabury, NE 37...
# 1  188 Johnson Views Suite 079\r\nLake Kathleen, ...
# ...

# %%
df.columns
# Out:
# Index(['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
#        'Avg_Area_Number_of_Bedrooms', 'Area_Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
# Avg_Area_Income                5000 non-null float64
# Avg_Area_House_Age             5000 non-null float64
# Avg_Area_Number_of_Rooms       5000 non-null float64
# Avg_Area_Number_of_Bedrooms    5000 non-null float64
# Area_Population                5000 non-null float64
# Price                          5000 non-null float64
# Address                        5000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 421.0+ KB

# %%
df.describe()
# Out:
#        Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# count      5000.000000         5000.000000               5000.000000
# mean      68322.477249            6.000865                  7.002456
# std        9611.524317            0.924711                  0.928696
# min       43192.114409            3.802599                  4.705015
# 25%       61746.077622            5.362350                  6.345038
# 50%       68804.286404            5.970429                  7.002902
# 75%       75072.224863            6.636170                  7.647200
# max       89946.900199            8.485444                  9.387913
#
#        Avg_Area_Number_of_Bedrooms  Area_Population         Price
# count                  5000.000000      5000.000000  5.000000e+03
# mean                      3.981330     36116.806876  1.232073e+06
# std                       1.234137      9581.183631  3.531176e+05
# min                       2.000000     10311.001394  1.593866e+04
# ...

# %%
df[df.duplicated()].sum()
# Out:
# Avg_Area_Income                0.0
# Avg_Area_House_Age             0.0
# Avg_Area_Number_of_Rooms       0.0
# Avg_Area_Number_of_Bedrooms    0.0
# Area_Population                0.0
# Price                          0.0
# Address                        0.0
# dtype: float64

# %%
df.drop_duplicates(inplace=True)

# %%
df.isna().sum()
# Out:
# Avg_Area_Income                0
# Avg_Area_House_Age             0
# Avg_Area_Number_of_Rooms       0
# Avg_Area_Number_of_Bedrooms    0
# Area_Population                0
# Price                          0
# Address                        0
# dtype: int64

# %%
df.columns=['Avg_Area_Income', 'Avg_Area_House_Age','Avg_Area_Number_of_Rooms','Avg_Area_Number_of_Bedrooms','Area_Population','Price','Address']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
# Avg_Area_Income                5000 non-null float64
# Avg_Area_House_Age             5000 non-null float64
# Avg_Area_Number_of_Rooms       5000 non-null float64
# Avg_Area_Number_of_Bedrooms    5000 non-null float64
# Area_Population                5000 non-null float64
# Price                          5000 non-null float64
# Address                        5000 non-null object
# dtypes: float64(6), object(1)
# memory usage: 293.0+ KB

# %%
df.head(5)
# Out:
#    Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# 0     79545.458574            5.682861                  7.009188
# 1     79248.642455            6.002900                  6.730821
# 2     61287.067179            5.865890                  8.512727
# 3     63345.240046            7.188236                  5.586729
# 4     59982.197226            5.040555                  7.839388
#
#    Avg_Area_Number_of_Bedrooms  Area_Population         Price  \
# 0                         4.09     23086.800503  1.059034e+06
# 1                         3.09     40173.072174  1.505891e+06
# 2                         5.13     36882.159400  1.058988e+06
# 3                         3.26     34310.242831  1.260617e+06
# 4                         4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\r\nLaurabury, NE 37...
# 1  188 Johnson Views Suite 079\r\nLake Kathleen, ...
# ...

# %%
df.describe()
# Out:
#        Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# count      5000.000000         5000.000000               5000.000000
# mean      68322.477249            6.000865                  7.002456
# std        9611.524317            0.924711                  0.928696
# min       43192.114409            3.802599                  4.705015
# 25%       61746.077622            5.362350                  6.345038
# 50%       68804.286404            5.970429                  7.002902
# 75%       75072.224863            6.636170                  7.647200
# max       89946.900199            8.485444                  9.387913
#
#        Avg_Area_Number_of_Bedrooms  Area_Population         Price
# count                  5000.000000      5000.000000  5.000000e+03
# mean                      3.981330     36116.806876  1.232073e+06
# std                       1.234137      9581.183631  3.531176e+05
# min                       2.000000     10311.001394  1.593866e+04
# ...

# %%
df['Avg_Area_Income'].median()
# Out:
# 68804.28640371616

# %%
df['Avg_Area_Income'].plot.box()

# %%
df["Avg_Area_Income"] = np.where(df["Avg_Area_Income"] >90000, 68804.28640371616,df['Avg_Area_Income'])

# %%
df["Avg_Area_Income"] = np.where(df["Avg_Area_Income"] <43000, 68804.28640371616,df['Avg_Area_Income'])

# %%
df['Avg_Area_Income'].plot.box()

# %%
df['Avg_Area_House_Age'].median()
# Out:
# 5.970428947124802

# %%
df['Avg_Area_House_Age'].plot.box()

# %%
df["Avg_Area_House_Age"]= np.where(df['Avg_Area_House_Age'] >8.5,5.970428947124802,df['Avg_Area_House_Age'])

# %%
df["Avg_Area_House_Age"]= np.where(df['Avg_Area_House_Age'] <3.8,5.970428947124802,df['Avg_Area_House_Age'])

# %%
df['Avg_Area_House_Age'].plot.box()

# %%
df['Avg_Area_Number_of_Rooms'].median()
# Out:
# 7.002901987201934

# %%
df['Avg_Area_Number_of_Rooms'].plot.box()

# %%
df["Avg_Area_Number_of_Rooms"]= np.where(df['Avg_Area_Number_of_Rooms'] >9.6,7.002901987201934, df['Avg_Area_Number_of_Rooms'])

# %%
df["Avg_Area_Number_of_Rooms"]= np.where(df['Avg_Area_Number_of_Rooms'] <4.6,7.002901987201934, df['Avg_Area_Number_of_Rooms'])

# %%
df['Avg_Area_Number_of_Rooms'].plot.box()

# %%
df['Avg_Area_Number_of_Bedrooms'].median()
# Out:
# 4.05

# %%
df['Avg_Area_Number_of_Bedrooms'].plot.box()

# %%
df['Area_Population'].plot.box()

# %%
df['Area_Population'].median()
# Out:
# 36199.406689260555

# %%
df["Area_Population"]=np.where(df['Area_Population']>62000,36199.406689260555,df['Area_Population'])

# %%
df["Area_Population"]=np.where(df['Area_Population']<10000,36199.406689260555,df['Area_Population'])

# %%
df['Area_Population'].plot.box()

# %%
df.describe()
# Out:
#        Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# count      5000.000000         5000.000000               5000.000000
# mean      68322.477249            6.000865                  7.002456
# std        9611.524317            0.924711                  0.928696
# min       43192.114409            3.802599                  4.705015
# 25%       61746.077622            5.362350                  6.345038
# 50%       68804.286404            5.970429                  7.002902
# 75%       75072.224863            6.636170                  7.647200
# max       89946.900199            8.485444                  9.387913
#
#        Avg_Area_Number_of_Bedrooms  Area_Population         Price
# count                  5000.000000      5000.000000  5.000000e+03
# mean                      3.981330     36116.806876  1.232073e+06
# std                       1.234137      9581.183631  3.531176e+05
# min                       2.000000     10311.001394  1.593866e+04
# ...

# %%
df['Area_Population'].plot.line()

# %%
df['Area_Population'].plot.density()

# %%
df['Avg_Area_Number_of_Bedrooms'].plot.line()

# %%
df['Avg_Area_Number_of_Bedrooms'].plot.density()

# %%
df['Avg_Area_Number_of_Rooms'].plot.line()

# %%
df['Avg_Area_Number_of_Rooms'].plot.density()

# %%
df['Avg_Area_House_Age'].plot.line()

# %%
df['Avg_Area_House_Age'].plot.density()

# %%
df['Avg_Area_Income'].plot.line()

# %%
df['Avg_Area_Income'].plot.density()

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,linewidths=7)

# %%
df.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#        Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# count      5000.000000         5000.000000               5000.000000
# mean      68322.477249            6.000865                  7.002456
# std        9611.524317            0.924711                  0.928696
# min       43192.114409            3.802599                  4.705015
# 10%       55531.811906            4.776638                  5.757030
# 25%       61746.077622            5.362350                  6.345038
# 50%       68804.286404            5.970429                  7.002902
# 75%       75072.224863            6.636170                  7.647200
# 90%       80955.288395            7.216551                  8.222708
# max       89946.900199            8.485444                  9.387913
#
#        Avg_Area_Number_of_Bedrooms  Area_Population         Price
# count                  5000.000000      5000.000000  5.000000e+03
# mean                      3.981330     36116.806876  1.232073e+06
# ...

# %%
l_column = list(df.columns)
l_column
# Out:
# ['Avg_Area_Income',
#  'Avg_Area_House_Age',
#  'Avg_Area_Number_of_Rooms',
#  'Avg_Area_Number_of_Bedrooms',
#  'Area_Population',
#  'Price',
#  'Address']

# %%
sns.pairplot(df)

# %%
l_column = list(df.columns) # Making a list out of column names
len_feature = len(l_column) # Length of column vector list
l_column
# Out:
# ['Avg_Area_Income',
#  'Avg_Area_House_Age',
#  'Avg_Area_Number_of_Rooms',
#  'Avg_Area_Number_of_Bedrooms',
#  'Area_Population',
#  'Price',
#  'Address']

# %%
X = df[l_column[0:len_feature]]
X.columns
# Out:
# Index(['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
#        'Avg_Area_Number_of_Bedrooms', 'Area_Population', 'Price', 'Address'],
#       dtype='object')

# %%
X=X.drop('Price',axis=1)
X.columns
# Out:
# Index(['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
#        'Avg_Area_Number_of_Bedrooms', 'Area_Population', 'Address'],
#       dtype='object')

# %%
X=X.drop('Address',axis=1)
X.columns
# Out:
# Index(['Avg_Area_Income', 'Avg_Area_House_Age', 'Avg_Area_Number_of_Rooms',
#        'Avg_Area_Number_of_Bedrooms', 'Area_Population'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Avg_Area_Income  Avg_Area_House_Age  Avg_Area_Number_of_Rooms  \
# count      5000.000000         5000.000000               5000.000000
# mean      68322.477249            6.000865                  7.002456
# std        9611.524317            0.924711                  0.928696
# min       43192.114409            3.802599                  4.705015
# 25%       61746.077622            5.362350                  6.345038
# 50%       68804.286404            5.970429                  7.002902
# 75%       75072.224863            6.636170                  7.647200
# max       89946.900199            8.485444                  9.387913
#
#        Avg_Area_Number_of_Bedrooms  Area_Population         Price
# count                  5000.000000      5000.000000  5.000000e+03
# mean                      3.981330     36116.806876  1.232073e+06
# std                       1.234137      9581.183631  3.531176e+05
# min                       2.000000     10311.001394  1.593866e+04
# ...

# %%
y = df['Price']

# %%
X.shape
# Out:
# (5000, 5)

# %%
y.shape
# Out:
# (5000,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %%
print("Training feature set size:",X_train.shape)
print("Test feature set size:",X_test.shape)
print("Training variable set size:",y_train.shape)
print("Test variable set size:",y_test.shape)
# Out:
# Training feature set size: (3500, 5)
# Test feature set size: (1500, 5)
# Training variable set size: (3500,)
# Test variable set size: (1500,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print("The intercept term of the linear model:", lm.intercept_)
# Out:
# The intercept term of the linear model: -2656824.4210598953

# %%
print("The coefficients of the linear model:", lm.coef_)
# Out:
# The coefficients of the linear model: [2.17007992e+01 1.66637952e+05 1.19636918e+05 6.92784667e+03
#  1.50683778e+01]

# %%
cdf = pd.DataFrame(data=lm.coef_, index=X_train.columns, columns=["Coefficients"])
cdf
# Out:
#                               Coefficients
# Avg_Area_Income                  21.700799
# Avg_Area_House_Age           166637.952443
# Avg_Area_Number_of_Rooms     119636.917888
# Avg_Area_Number_of_Bedrooms    6927.846674
# Area_Population                  15.068378

# %%
train_pred = lm.predict(X_train)

# %%
train_pred
# Out:
# array([1434961.16201155,  742844.04369553, 1743883.37653058, ...,
#        1177749.35731563, 1386872.90516691, 1368955.91477943])

# %%
metrics.mean_squared_error(y_train,train_pred)
# Out:
# 26131890761.681355

# %%
test_pred = lm.predict(X_test)

# %%
metrics.mean_squared_error(y_test,test_pred)
# Out:
# 28369818154.020363

# %%
metrics.mean_absolute_error(y_train,train_pred)
# Out:
# 108234.36642947374

# %%
np.sqrt(metrics.mean_squared_error(y_train,train_pred))
# Out:
# 161653.61351260092

# %%
print("R-squared value of this fit:",round(metrics.r2_score(y_train,train_pred),3))
# Out:
# R-squared value of this fit: 0.786

# %%
predictions = lm.predict(X_test)
print ("Type of the predicted object:", type(predictions))
print ("Size of the predicted object:", predictions.shape)
# Out:
# Type of the predicted object: <class 'numpy.ndarray'>
# Size of the predicted object: (1500,)

# %%
plt.figure(figsize=(10,7))
plt.title("Actual vs. predicted house prices",fontsize=25)
plt.xlabel("Actual test set house prices",fontsize=18)
plt.ylabel("Predicted house prices", fontsize=18)
plt.scatter(x=y_test,y=predictions)

# %%
plt.figure(figsize=(10,7))
plt.title("Histogram of residuals to check for normality",fontsize=25)
plt.xlabel("Residuals",fontsize=18)
plt.ylabel("Kernel density", fontsize=18)
sns.distplot([y_test-predictions])

# %%
plt.figure(figsize=(10,7))
plt.title("Residuals vs. predicted values plot (Homoscedasticity)\n",fontsize=25)
plt.xlabel("Predicted house prices",fontsize=18)
plt.ylabel("Residuals", fontsize=18)
plt.scatter(x=predictions,y=y_test-predictions)

# %%
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_train,train_pred))
print("Mean square error (MSE):", metrics.mean_squared_error(y_train,train_pred))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_train,train_pred)))
# Out:
# Mean absolute error (MAE): 108234.36642947374
# Mean square error (MSE): 26131890761.681355
# Root mean square error (RMSE): 161653.61351260092

# %%
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# Mean absolute error (MAE): 111724.48209338493
# Mean square error (MSE): 28369818154.020363
# Root mean square error (RMSE): 168433.42350620427

# %%
print("R-squared value of predictions:",round(metrics.r2_score(y_test,predictions),3))
# Out:
# R-squared value of predictions: 0.782
